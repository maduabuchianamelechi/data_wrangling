# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ## Maduabuchi Anamelechi
#
# ### Introduction
#
# My analysis spanned through checking the distribution of rating ratio across different tweets.
# Then i moved on to check if there is a correlation between the number of images added to a tweet and the number of likes the tweet got. and a couple of other analysis.

# %% [markdown]
# ### Analysis

# %% [markdown]
# To check the rating ratio across tweets i divided the rating numerator by the rating denominator to get the rating ratio. Form the analysis as shown in the chart below, there were two outliers that over shoot the range of the rating ratio's.

# %% [markdown]
# ![Screenshot%20%2859%29.png](attachment:Screenshot%20%2859%29.png)

# %% [markdown]
# After making a deep dive on the two outliers, i discovered the tweets was made for fun (comedic) as seen below.

# %% [markdown]
# ![Screenshot%20%281%29.png](attachment:Screenshot%20%281%29.png)![Screenshot%20%282%29.png](attachment:Screenshot%20%282%29.png)

# %% [markdown]
# ### Secondly
#
# I did an analysis to check if the number of images contained in a tweet has a correlation on the number of likes the tweet gets.
#
# As seen below, the more the number of images in the tweet the more likes it gets.

# %% [markdown]
# ![Screenshot%20%2860%29.png](attachment:Screenshot%20%2860%29.png)

# %% [markdown]
# ### Thirdly
#
# I checked if the dogs that got the highest number of rating ratio also got the highest number of likes on twitter.
# But the analysis showed that there's no correlation between them, as the top 10 didn't show up at all in dogs with the highest number of likes.

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'act_report.ipynb'])
# Out:
# 0
